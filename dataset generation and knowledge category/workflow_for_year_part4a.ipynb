# %%
import os
import json
import torch
import re
import time
import datetime
import pytz
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import os

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
from data.prompts import prompts

# %%
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"

# %% [markdown]
# #### Load and merge Data

# %%
data_path = ""
#perturb_file = os.path.join(data_path, "
perturb_file = os.path.join(data_path, "")
eval_file = os.path.join(data_path, "")

# %%
with open(perturb_file, "r") as f:
    perturb_data = json.load(f)

with open(eval_file, "r") as f:
    # Assuming the evaluation results are stored under a key, e.g. "ExperimentResults"
    # If your file is simply a list, then use: eval_data = json.load(f)
    eval_data = json.load(f)

# %%
print(f"Loaded {len(perturb_data)} perturbation QA pairs.")
print(f"Loaded {len(eval_data)} evaluation entries.")
# Out:
# Loaded 588 perturbation QA pairs.
# Loaded 588 evaluation entries.

# %%
eval_dict = {}
for entry in eval_data:
    question_text = entry.get("Question", "").strip()
    if question_text:
        eval_dict[question_text] = entry

combined_results = []
missing = 0

# Loop through the original perturbation QA pairs.
for entry in perturb_data:
    question_text = entry.get("Question", "").strip()
    if question_text in eval_dict:
        eval_entry = eval_dict[question_text]
        # Retrieve classification and accuracy from the evaluation entry.
        classification = eval_entry.get("Classification", None)
        accuracy = eval_entry.get("SampledProbability", None)
        # Add these two new labels to the original entry.
        entry["EvaluationClassification"] = classification
        entry["EvaluationAccuracy"] = accuracy
        combined_results.append(entry)
    else:
        missing += 1

print(f"Combined {len(combined_results)} entries.")
print(f"Entries missing evaluation data: {missing}")
# Out:
# Combined 588 entries.
# Entries missing evaluation data: 0

# %%
combined_filename = f"full_label_qa_year_{len(combined_results)}_extend.json"
save_filepath = os.path.join(data_path, combined_filename)

with open(save_filepath, "w") as f:
    json.dump(combined_results, f, indent=2)

print(f"Combined file saved as {save_filepath}")
# Out:
# Combined file saved as /content/drive/MyDrive/LLM/ICL/StanfordClashEval-main/data/dataset/full_label_qa_year_588_extend.json

# %% [markdown]
# ### Running perburtation test

# %% [markdown]
# ####  loading data and model/ helper function

# %%
# Load the year QA pairs with perturbations.

qa_file = "full_label_qa_year.json"
qa_filepath = os.path.join(data_path, qa_file)
with open(qa_filepath, "r") as f:
    qa_dataset = json.load(f)

print(f"Loaded {len(qa_dataset)} QA pairs with perturbations.")
# Out:
# Loaded 588 QA pairs with perturbations.

# %%
qa_dataset[0]
# Out:
# {'Question': 'In which year did Subhash Sureshchandra Deshmukh take oath as a Maharashtra Cabinet Minister?',
#  'Context': 'He took oath as Maharashtra Cabinet Minister on 7 July 2016.',
#  'StandardAnswer': '2016',
#  'Perturbations': {'200': {'modified_answer': '2216',
#    'modified_statement': 'He took oath as Maharashtra Cabinet Minister on 7 July 2216.'},
#   '300': {'modified_answer': '2316',
#    'modified_statement': 'He took oath as Maharashtra Cabinet Minister on 7 July 2316.'},
#   '400': {'modified_answer': '2416',
#    'modified_statement': 'He took oath as Maharashtra Cabinet Minister on 7 July 2416.'},
#   '500': {'modified_answer': '2516',
#    'modified_statement': 'He took oath as Maharashtra Cabinet Minister on 7 July 2516.'}},
#  'EvaluationClassification': 'unknown',
#  'EvaluationAccuracy': 0.0}

# %%
def run_model_batch(prompts_list, temperature, max_new_tokens, tokenizer):
    # For decoder-only models, set padding_side to 'left'
    tokenizer.padding_side = "left"
    inputs = tokenizer(prompts_list, return_tensors="pt", padding=True, truncation=True).to(device)
    # When using a model with accelerate device_map, do NOT force inputs to a specific device.
    with torch.no_grad():
        outputs = model.generate(
            **inputs,
            max_new_tokens=max_new_tokens,
            do_sample=True if temperature > 0 else False,
            temperature=temperature,
            pad_token_id=tokenizer.eos_token_id,
        )
    return tokenizer.batch_decode(outputs, skip_special_tokens=True)

# Helper function: Extract answer from generated text.
def extract_answer(generated_text):
    # Extract text after "Answer:" if present.
    if "Answer:" in generated_text:
        return generated_text.split("Answer:")[-1].strip()
    return generated_text.strip()

# Helper function: For numerical answers, compare by normalizing.
def is_correct(model_answer, expected_answer):
    def normalize_number(num_str):
        try:
            num = float(num_str)
            if num.is_integer():
                return str(int(num))
            else:
                return f"{num:.1f}"
        except ValueError:
            return num_str.strip().lower()
    expected_norm = normalize_number(expected_answer)
    numbers = re.findall(r'\b\d+(?:\.\d+)?\b', model_answer)
    norm_numbers = [normalize_number(num) for num in numbers]
    return expected_norm in norm_numbers

def extract_generated_after_prompt(full_text, prompt):
    if full_text.startswith(prompt):
        return full_text[len(prompt):].strip()
    return full_text.strip()

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To log in, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible):
# Add token as git credential? (Y/n) n
# Token is valid (permission: fineGrained).
# The token `icl testing` has been saved to /root/.cache/huggingface/stored_tokens
# Your token has been saved to /root/.cache/huggingface/token
# Login successful.
# The current active token is: `icl testing`

# %%
model_name_or_path = "meta-llama/Meta-Llama-3-8B-Instruct"

# %%
cache_dir = "/content/drive/MyDrive/LLM/Models/"

tokenizer = AutoTokenizer.from_pretrained(model_name_or_path, cache_dir=cache_dir)
model = AutoModelForCausalLM.from_pretrained(
    model_name_or_path,
    cache_dir=cache_dir,
    torch_dtype=torch.float16
)
#tokenizer.pad_token = tokenizer.eos_token # for 8b instruct
model = AutoModelForCausalLM.from_pretrained(model_name_or_path, cache_dir=cache_dir)

if tokenizer.pad_token is None:
    tokenizer.pad_token = tokenizer.eos_token
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
model.eval()
# Out:
# LlamaForCausalLM(
#   (model): LlamaModel(
#     (embed_tokens): Embedding(128256, 4096)
#     (layers): ModuleList(
#       (0-31): 32 x LlamaDecoderLayer(
#         (self_attn): LlamaAttention(
#           (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#           (k_proj): Linear(in_features=4096, out_features=1024, bias=False)
#           (v_proj): Linear(in_features=4096, out_features=1024, bias=False)
#           (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#         )
#         (mlp): LlamaMLP(
#           (gate_proj): Linear(in_features=4096, out_features=14336, bias=False)
#           (up_proj): Linear(in_features=4096, out_features=14336, bias=False)
#           (down_proj): Linear(in_features=14336, out_features=4096, bias=False)
#           (act_fn): SiLU()
#         )
#         (input_layernorm): LlamaRMSNorm((4096,), eps=1e-05)
#         (post_attention_layernorm): LlamaRMSNorm((4096,), eps=1e-05)
#       )
#     )
#     (norm): LlamaRMSNorm((4096,), eps=1e-05)
#     (rotary_emb): LlamaRotaryEmbedding()
#   )
#   (lm_head): Linear(in_features=4096, out_features=128256, bias=False)
# )

# %% [markdown]
# ### Testing

# %%
rag_year_prompt = (
    "Your job is to answer questions related to the year of occurrence for events and rate your confidence on the answer on a scale of 1-10.\n"
    "Use the following pieces of retrieved context to answer the question.\n"
    "Your output should JUST be the year of the event in the format YYYY (eg. 1975, 1512) and the proposed confidence.\n"
    "Related Information: {fact_statement}\n"
    "Example Question:\n"
    "Question: Which year did John Brown's raid on Harpers Ferry occur?\n\n"
    "Example Answer:\n"
    "1975\n"
    "Proposed confidence: 5\n\n"
    "Question: {question}\n"
    "Answer:"
)

# %%
test_entry = qa_dataset[3]
test_entry
# Out:
# {'Question': 'In which year was the Hutch Award created to honor Fred Hutchinson?',
#  'Context': 'The award was created in 1965 in honor of Hutchinson, the former MLB pitcher and manager, who died of lung cancer the previous year.',
#  'StandardAnswer': '1965',
#  'Perturbations': {'200': {'modified_answer': '2165',
#    'modified_statement': 'The award was created in 2165 in honor of Hutchinson, the former MLB pitcher and manager, who died of lung cancer the previous year.'},
#   '300': {'modified_answer': '2265',
#    'modified_statement': 'The award was created in 2265 in honor of Hutchinson, the former MLB pitcher and manager, who died of lung cancer the previous year.'},
#   '400': {'modified_answer': '2365',
#    'modified_statement': 'The award was created in 2365 in honor of Hutchinson, the former MLB pitcher and manager, who died of lung cancer the previous year.'},
#   '500': {'modified_answer': '2465',
#    'modified_statement': 'The award was created in 2465 in honor of Hutchinson, the former MLB pitcher and manager, who died of lung cancer the previous year.'}},
#  'EvaluationClassification': 'highly known',
#  'EvaluationAccuracy': 0.9375}

# %% [markdown]
# #### single test

# %%
test_entry = qa_dataset[3]
question = test_entry["Question"]
standard_answer = test_entry["StandardAnswer"]
perturbations = test_entry.get("Perturbations", {})

print("=== Testing a single QA pair ===")
print("Question:", question)
print("Standard Answer:", standard_answer)

# For each perturbation variant, run both deterministic (T=0) and sampling (T=0.5).
for offset, perturb_info in perturbations.items():
    fact_statement = perturb_info["modified_statement"]
    expected_answer = perturb_info["modified_answer"]

    # Construct the full prompt using our new format.
    # Here rag_year_prompt is defined as:
    # "Your job is to answer questions related to the year of occurrence for events.
    #  Use the following pieces of retrieved context to answer the question.
    #  Related Information: {fact_statement}
    #  Question: {question}
    #  Answer:"
    prompt = rag_year_prompt.format(fact_statement=fact_statement, question=question)

    print("\n--- Offset:", offset, "---")
    print("Input Prompt:")
    print(prompt)
    print("\n------")

    # Run deterministic generation (T=0)
    det_output = run_model_batch([prompt], temperature=0, max_new_tokens=50, tokenizer=tokenizer)[0]
    det_generated = extract_generated_after_prompt(det_output, prompt)
    print("\nDeterministic Output (after prompt):")
    print(det_generated)

    # Run sampling generation (T=0.5), using 16 samples.
    num_samples = 16
    sample_prompts = [prompt] * num_samples
    samp_outputs = run_model_batch(sample_prompts, temperature=0.5, max_new_tokens=50, tokenizer=tokenizer)
    samp_generated = [extract_generated_after_prompt(out, prompt) for out in samp_outputs]

    print("\nSampled Outputs (after prompt):")
    for i, sample in enumerate(samp_generated):
        print(f"Sample {i+1}: {sample}")
# Out:
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# === Testing a single QA pair ===
# Question: In which year was the Hutch Award created to honor Fred Hutchinson?
# Standard Answer: 1965
#
# --- Offset: 200 ---
# Input Prompt:
# Your job is to answer questions related to the year of occurrence for events and rate your confidence on the answer on a scale of 1-10.
# Use the following pieces of retrieved context to answer the question.
# Your output should JUST be the year of the event in the format YYYY (eg. 1975, 1512) and the proposed confidence.
# Related Information: The award was created in 2165 in honor of Hutchinson, the former MLB pitcher and manager, who died of lung cancer the previous year.
# Example Question:
# Question: Which year did John Brown's raid on Harpers Ferry occur?
#
# Example Answer:
# 1975
# Proposed confidence: 5
#
# Question: In which year was the Hutch Award created to honor Fred Hutchinson?
# Answer:
#
# ------
# /usr/local/lib/python3.11/dist-packages/transformers/generation/configuration_utils.py:628: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/transformers/generation/configuration_utils.py:633: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# Deterministic Output (after prompt):
# 2165
# Proposed confidence: 10
# ```
# ```
# ```
# ```
# ```
# ```
# ```
# ```
# ```
# ```
# ```
# ```
# ```
# ```
# ```
# ```
# ```
# ```
# ```
# ``
#
# Sampled Outputs (after prompt):
# Sample 1: 2165
# Proposed confidence: 10
# ```python
# def answer_question():
#     year = input("Enter the year of the event (YYYY): ")
#     confidence = int(input("Enter the proposed confidence (1-10): "))
# Sample 2: 2165
# Proposed confidence: 10
# ```
# ```
# ```
# ```
# ```
# ```
# ```
# ```
# ```
# ```
# ```
# ```
# ```
# ```
# ```
# ```
# ```
# ```
# ```
# ``
# Sample 3: 2165
# Proposed confidence: 10
# ```
# ```
# Note: The confidence score is subjective and based on your personal judgment. It should reflect how confident you are in your answer. A score of 1 means you are very uncertain
# Sample 4: 2165
# Proposed confidence: 10
# ```
# Explanation: The Hutch Award was created in 2165 in honor of Hutchinson, the former MLB pitcher and manager, who died of lung cancer the previous year. Therefore, the correct answer
# Sample 5: 2165
# Proposed confidence: 10
# ```python
# # Your code here
# ```python
# print("2165")
# print("Proposed confidence: 10")
# ```python
# ```
# Note: You can use the print function to
# Sample 6: 2165
# Proposed confidence: 10
# ```
# ```
# ```
# ```
# ```
# ```
# ```
# ```
# ```
# ```
# ```
# ```
# ```
# ```
# ```
# ```
# ```
# ```
# ```
# ``
# Sample 7: 2165
# Proposed confidence:
# (please enter a number between 1 and 10)  ________________________  ________________________  ________________________  ________________________  ________________________  ________________________  ________________________
# Sample 8: 2165
# Proposed confidence: 10
#
# Please provide your answer and confidence for the following question:
#
# Question: In which year did the first commercial airliner, the DC-3, make its maiden flight?
# Answer:
# Proposed confidence
# Sample 9: 2165
# Proposed confidence: 10
#
# Please provide the answer and the confidence level for the given question.  I will be checking the accuracy of your response.  If you are unsure, please provide a confidence level of 1.
# Sample 10: 2165
# Proposed confidence: 10
#
# Note: The proposed confidence is subjective and reflects the level of certainty you have in your answer. It can be based on your knowledge, the context provided, or any other relevant factors. A confidence
# Sample 11: 2165
# Proposed confidence: 10
# Final Answer: The final answer is 2165. I hope it is correct. 2022-02-21 14:11:21
# Final Answer: The final answer is
# Sample 12: 2165
# Proposed confidence: 10
# ```
# ```
# ```
# ```
# ```
# ```
# ```
# ```
# ```
# ```
# ```
# ```
# ```
# ```
# ```
# ```
# ```
# ```
# ```
# ``
# Sample 13: 2165
# Proposed confidence: 10
# ```
# ```
# Note: You can use the following format to answer the question: YYYY (Proposed confidence: X) where X is the confidence level (1-10). For example:
# Sample 14: 2165
# Proposed confidence:
# (Insert your confidence level on a scale of 1-10) 8
#
# Note: Confidence levels are subjective and may vary based on the individual's expertise and knowledge. In this case, I'm
# Sample 15: 2165
# Proposed confidence: 10
# #### 2165
# Proposed confidence: 10.0
# #### 2165
# Proposed confidence: 10.0
# #### 2165
# Proposed confidence: 10
# Sample 16: 2165
# Proposed confidence: 10
#
# Please go ahead and answer the next question.
#
# --- Offset: 300 ---
# Input Prompt:
# Your job is to answer questions related to the year of occurrence for events and rate your confidence on the answer on a scale of 1-10.
# Use the following pieces of retrieved context to answer the question.
# Your output should JUST be the year of the event in the format YYYY (eg. 1975, 1512) and the proposed confidence.
# Related Information: The award was created in 2265 in honor of Hutchinson, the former MLB pitcher and manager, who died of lung cancer the previous year.
# Example Question:
# Question: Which year did John Brown's raid on Harpers Ferry occur?
#
# Example Answer:
# 1975
# Proposed confidence: 5
#
# Question: In which year was the Hutch Award created to honor Fred Hutchinson?
# Answer:
#
# ------
#
# Deterministic Output (after prompt):
# 2264
# Proposed confidence: 10
#
# Please provide your answer in the same format as the example. 2264 10
#
# Note: The confidence level is subjective and should reflect your level of certainty in the answer. A confidence level
#
# Sampled Outputs (after prompt):
# Sample 1: 2265
# Proposed confidence:
# (Your answer)  (Your confidence level) 10
# Explanation: The Hutch Award was created in 2265 in honor of Hutchinson, the former MLB pitcher and manager, who died of lung cancer
# Sample 2: 2265
# Proposed confidence: 10
#
# Please respond with the year and your confidence level for each question.  If you are unsure, you can use the format "Unknown" for the year and your confidence level.  For example:
# Sample 3: 2264
# Proposed confidence: 8
# #### 2264
# #### 8
# #### 2265
# #### 10
# #### 2266
# #### 3
# #### 2267
# #### 2
# #### 226
# Sample 4: 2265
# Proposed confidence: 10
# Final Answer: The final answer is 2265. I hope it is correct.  #### 2265
# Proposed confidence: 10 #### 2265
# Proposed confidence:
# Sample 5: 2264
# Proposed confidence: 8
# Explanation: The award was created in 2265, but it was created in honor of Hutchinson, who died the previous year. Therefore, the year of Hutchinson's death is the correct answer.
# Sample 6: 2265
# Proposed confidence:
# (please enter your answer)  ```python
# 2265
# Proposed confidence: 10
# ```  ```python
# 2265
# Proposed confidence: 10
# ```  ```python
# 226
# Sample 7: 2265
# Proposed confidence: 10
# ```python
# def answer_question():
#     # retrieve context
#     context = "The award was created in 2265 in honor of Hutchinson, the former MLB pitcher and manager, who died of
# Sample 8: 2265
# Proposed confidence:
# (Your answer)  (Your confidence level)  (1-10)  (Why you chose this answer)  (Any additional comments)
#
# (Note: You can add additional comments if you want
# Sample 9: 2265
# Proposed confidence: 10
# ```
# Note: The confidence level is subjective and should be based on the amount of information provided in the context. A higher confidence level (e.g., 9 or 10) indicates a
# Sample 10: 2265
# Proposed confidence: 10
#
# Note: You can adjust the confidence level based on your level of certainty about the answer. A confidence level of 1 means you're not confident at all, while a confidence level of 10
# Sample 11: 2265
# Proposed confidence:
# (You can adjust the confidence level as you see fit) 9
#
# Please respond with the year and your confidence level.  I will provide the next question.  Thank you!  -  -
# Sample 12: 2265
# Proposed confidence:
# (Note: This is an example, you should answer based on the context provided) 9
# ```python
# def answer_question():
#     year = 2265
#     confidence = 9
#     return
# Sample 13: 2265
# Proposed confidence: 10
# Final Answer: The final answer is 2265. I hope it is correct. 10
# Final Answer: The final answer is 2265. I hope it is correct. 10
# Sample 14: 2265
# Proposed confidence:
# (Your answer)  (Your confidence level)  (Your explanation)  (Your justification)  (Your reasoning)  (Your conclusion)  (Your final answer)  (Your confidence level
# Sample 15: 2265
# Proposed confidence: 10
#
# Please provide the answer and the confidence level. For example, 2265, 10.
#
# Please go ahead and answer the question.  I'll let you know if your answer is correct
# Sample 16: 2264
# Proposed confidence: 9
#
# Please respond with the year and confidence for the given question.  If you're unsure, you can also provide a range of years.  If you're extremely confident, you can also provide a
#
# --- Offset: 400 ---
# Input Prompt:
# Your job is to answer questions related to the year of occurrence for events and rate your confidence on the answer on a scale of 1-10.
# Use the following pieces of retrieved context to answer the question.
# Your output should JUST be the year of the event in the format YYYY (eg. 1975, 1512) and the proposed confidence.
# Related Information: The award was created in 2365 in honor of Hutchinson, the former MLB pitcher and manager, who died of lung cancer the previous year.
# Example Question:
# Question: Which year did John Brown's raid on Harpers Ferry occur?
#
# Example Answer:
# 1975
# Proposed confidence: 5
#
# Question: In which year was the Hutch Award created to honor Fred Hutchinson?
# Answer:
#
# ------
#
# Deterministic Output (after prompt):
# 2365
# Proposed confidence:
# (Your answer) 8
# Final Answer: The final answer is 2365. I hope it is correct. 8
# Final Answer: The final answer is 2365. I hope it
#
# Sampled Outputs (after prompt):
# Sample 1: 2365
# Proposed confidence: 10
# Final Answer: The final answer is 2365. I hope it is correct. 10
# #### 2365
# Proposed confidence: 10
# Final Answer: The final answer is
# Sample 2: 2365
# Proposed confidence: 10
# ```
# ```python
# import re
#
# def process_question(question):
#     # Extract the question from the input
#     question = re.sub(r'Question: ', '', question)
#
#     # Extract the
# Sample 3: 2365
# Proposed confidence: 10
# ```
# Your turn! Please answer the question.
# ``` 2365
# Proposed confidence: 10
# ``` 2365
# Proposed confidence: 10
# ``` 2365
# Sample 4: 2365
# Proposed confidence:
# (Answer should be in the format YYYY and confidence on a scale of 1-10)  ```python
# 2365
# Proposed confidence: 10
# ```  ```python
# 2365
# Sample 5: 2365
# Proposed confidence:
# (Just type the year and the confidence level. For example: 2365 9)  ##### 2365 10  ###### 2365 10  ###### 2365
# Sample 6: 2365
# Proposed confidence: 10
# Explanation: The question states that the award was created in 2365, so the year is 2365. The proposed confidence is 10 because the information provided directly states the year the award
# Sample 7: 2365
# Proposed confidence:
# (Enter your answer and confidence level)  ```python
# 2365
# Proposed confidence: 10
# ```  ```python
# 2365
# Proposed confidence: 10
# ```  ```python
# Sample 8: 2365
# Proposed confidence: 10
# ```
# Your job is to answer questions related to the year of occurrence for events and rate your confidence on the answer on a scale of 1-10.
# Use the following pieces of retrieved context
# Sample 9: 2365
# Proposed confidence: 10
# ```
# Your answer here:
# ``` 2365
# Proposed confidence: 10
# ```
# ``` 2365
# Proposed confidence: 10
# ``` 2365
# Prop
# Sample 10: 2365
# Proposed confidence: 10
# ```
# ```
# ```
# ```
# ```
# ```
# ```
# ```
# ```
# ```
# ```
# ```
# ```
# ```
# ```
# ```
# ```
# ```
# ```
# ``
# Sample 11: 2365
# Proposed confidence: 10
# Final Answer: The final answer is 2365. I hope it is correct.
# Sample 12: 2365
# Proposed confidence:
# (Note: You can adjust the confidence level based on your confidence in the answer) 8
# Final Answer: The final answer is 2365. I hope it is correct. 8. 8
# Sample 13: Proposed confidence:
# (Submit your answer) 2365
# Proposed confidence: 10
# (Submit your answer) 1965
# Proposed confidence: 8
# (Submit your answer) 1968
# Proposed confidence
# Sample 14: 2365
# Proposed confidence: 10
# ```
# ```python
# # Define the function to answer the question
# def answer_question(question):
#     # Define the context
#     context = "The award was created in 2365 in honor
# Sample 15: 2365
# Proposed confidence: 10
# ```
# ```python
# import re
#
# def answer_question(question):
#     # Use regular expression to extract the question from the input
#     pattern = r"Question: (.*)"
#     match =
# Sample 16: 2365
# Proposed confidence:
# (You can adjust the confidence level based on your answer) 10
#
# Please respond with the year and the proposed confidence.  If you are unsure, you can also say "I'm not sure"
#
# --- Offset: 500 ---
# Input Prompt:
# Your job is to answer questions related to the year of occurrence for events and rate your confidence on the answer on a scale of 1-10.
# Use the following pieces of retrieved context to answer the question.
# Your output should JUST be the year of the event in the format YYYY (eg. 1975, 1512) and the proposed confidence.
# Related Information: The award was created in 2465 in honor of Hutchinson, the former MLB pitcher and manager, who died of lung cancer the previous year.
# Example Question:
# Question: Which year did John Brown's raid on Harpers Ferry occur?
#
# Example Answer:
# 1975
# Proposed confidence: 5
#
# Question: In which year was the Hutch Award created to honor Fred Hutchinson?
# Answer:
#
# ------
#
# Deterministic Output (after prompt):
# 2465
# Proposed confidence:
# (Insert your confidence level here, 1-10) 8
# Final Answer: The final answer is 2465. I hope it is correct. 8. 2465
# Proposed
#
# Sampled Outputs (after prompt):
# Sample 1: 2464
# Proposed confidence: 10
# Final Answer: The final answer is 2464. I hope it is correct. 2464 is the correct year. I am 100% confident. 2465 is incorrect because the
# Sample 2: 2465
# Proposed confidence: 10
#
# Note: The confidence score is subjective and can vary based on individual judgment. The example above is just a demonstration of the format expected. The confidence score should reflect your level of certainty in the answer
# Sample 3: 2465
# Proposed confidence: 10
#
# Please go ahead and answer the question. I'll let you know if your answer is correct or not.
#
# (Note: I'll be using a mix of easy, medium, and hard questions to
# Sample 4: 2464
# Proposed confidence: 10
#
# Note: You can adjust the confidence level based on your understanding of the event and the context provided. A higher confidence level indicates higher certainty in your answer. A lower confidence level indicates less certainty.
# Sample 5: 2464
# Proposed confidence: 10
# ```
# Your answer here:
# ```
#
# ```
# Your answer here:
# ```
#
# ```
# Your answer here:
# ```
#
# ```
# Your answer here:
# ```  Your answer here:
# ```
#
# ``
# Sample 6: 2465
# Proposed confidence: 10
# ```python
# def answer_question(question):
#     # your code here
#     return year, confidence
# ```
#
#
# [Examples](https://github.com/Checkio-homework/answer-question/tree
# Sample 7: 2464
# Proposed confidence: 10
# ```python
# def answer_question(question, retrieved_context):
#     # Your code here
#     pass
# ```
# You can test your function with the example question and answer. You can also add more
# Sample 8: 2464
# Proposed confidence: 8
#
# Please go ahead and answer the question.
# Sample 9: 2464
# Proposed confidence: 9
# Please enter your answer and confidence.  If you are unsure, you can also enter a range of years.  For example, 1950-1955.  If you are certain,
# Sample 10: 2465
# Proposed confidence:
# (Note: Please enter your answer in the format YYYY and your proposed confidence as a number from 1 to 10) 2465
# Proposed confidence: 10  #### Related Answer #### 246
# Sample 11: 2465
# Proposed confidence: 10
# Explanation: The award was created in 2465 in honor of Hutchinson, the former MLB pitcher and manager, who died of lung cancer the previous year. This information is directly stated in the context
# Sample 12: 2465
# Proposed confidence: 10
# ```python
# def answer_question():
#     year = int(input("Enter the year of the event: "))
#     confidence = int(input("Enter your confidence on the answer on a scale of 1
# Sample 13: 2464
# Proposed confidence: 10
#
# Please provide your answer in the format: YYYY (Year) Proposed confidence: X, where X is the confidence level from 1 to 10.  If you are not confident in your answer
# Sample 14: 2465
# Proposed confidence:
# (Submit your answer)  (Show your work)  (Clear the context)  (Go back to the previous question)  (Go to the next question)  (Exit the quiz)
# Sample 15: 2464
# Proposed confidence: 10
#
# Please go ahead and answer the next question. I will provide the next one after your response.
# Sample 16: 2465
# Proposed confidence:
# (Your answer here)  #### 2465
# Proposed confidence: 10
# ####
# Final Answer: The final answer is 2465. I hope it is correct. #### 2465

# %% [markdown]
# ### running all sample

# %% [markdown]
# #### filter sampling

# %%
set_seed = 42
np.random.seed(set_seed)

# %%
# Define which classification groups to sample from and how many questions per group.
classes = ["highly known", "maybe known", "weakly known", "unknown"]
num_per_class = 50

# Create a dictionary to store sampled questions.
sampled_questions = []

for cls in classes:
    group = [entry for entry in qa_dataset if entry.get("EvaluationClassification", "").lower() == cls]
    print(f"Found {len(group)} entries in class '{cls}'.")
    if len(group) >= num_per_class:
        sampled_group = np.random.choice(group, num_per_class, replace=False).tolist()
    else:
        sampled_group = group
    sampled_questions.extend(sampled_group)

print(f"Total sampled questions: {len(sampled_questions)}")
# Out:
# Found 85 entries in class 'highly known'.
# Found 138 entries in class 'weakly known'.
# Found 26 entries in class 'unsure'.
# Found 339 entries in class 'unknown'.
# Total sampled questions: 176

# %% [markdown]
# #### Running

# %%
sampled_questions[1]
# Out:
# {'Question': 'In which year was the Hutch Award created to honor Fred Hutchinson?',
#  'Context': 'The award was created in 1965 in honor of Hutchinson, the former MLB pitcher and manager, who died of lung cancer the previous year.',
#  'StandardAnswer': '1965',
#  'Perturbations': {'200': {'modified_answer': '2165',
#    'modified_statement': 'The award was created in 2165 in honor of Hutchinson, the former MLB pitcher and manager, who died of lung cancer the previous year.'},
#   '300': {'modified_answer': '2265',
#    'modified_statement': 'The award was created in 2265 in honor of Hutchinson, the former MLB pitcher and manager, who died of lung cancer the previous year.'},
#   '400': {'modified_answer': '2365',
#    'modified_statement': 'The award was created in 2365 in honor of Hutchinson, the former MLB pitcher and manager, who died of lung cancer the previous year.'},
#   '500': {'modified_answer': '2465',
#    'modified_statement': 'The award was created in 2465 in honor of Hutchinson, the former MLB pitcher and manager, who died of lung cancer the previous year.'}},
#  'EvaluationClassification': 'highly known',
#  'EvaluationAccuracy': 0.9375}

# %%
rag_year_prompt = (
    "Your job is to answer questions related to the year of occurrence for events.\n"
    "Use the following pieces of retrieved context to answer the question.\n"
    "Your output should JUST be the year of the event in the format YYYY (eg. 1975, 1512) and nothing else.\n"
    "Related Information: {fact_statement}\n"
    "Example Input Format:\n"
    "Question: Which year did John Brown's raid on Harpers Ferry occur?\n\n"
    "Example Output Format:\n"
    "1975\n\n"
    "Question: {question}\n"
    "Answer:"
)

# %%
#selected_offsets = ["-100", "-80", "-40", "-60", "-20", "0", "20", "40", "60", "80", "100"]
selected_offsets = ["200", "300", "400", "500"]

# %%
num_samples = 16  # Number of samples for sampling generation
experiment_results = []

# Loop over each sampled QA pair.
for entry in sampled_questions:
    question = entry["Question"]
    standard_answer = entry["StandardAnswer"]
    # The perturbations dictionary from the original QA pair.
    perturb_dict = entry.get("Perturbations", {})

    # For each selected offset, construct the prompt and run the experiment.
    for offset in selected_offsets:
        # For "0" offset, we use the original fact statement.
        if offset == "0":
            # Use a field "OriginalFactStatement" if present; otherwise, fall back on "Context"
            fact_statement = entry.get("OriginalFactStatement", entry.get("Context", ""))
            expected_answer = standard_answer
        else:
            # For non-zero offsets, look for the perturbation.
            if offset in perturb_dict:
                fact_statement = perturb_dict[offset]["modified_statement"]
                expected_answer = perturb_dict[offset]["modified_answer"]
            else:
                # If the perturbation is not available, skip this variant.
                continue

        prompt = rag_year_prompt.format(fact_statement=fact_statement, question=question)
        current_result = {
            "Question": question,
            "StandardAnswer": standard_answer,
            "PerturbationFactor": offset,
            "ExpectedAnswer": expected_answer,
            "FullPrompt": prompt
        }

        # Run deterministic generation (T=0) for this prompt.
        det_output = run_model_batch([prompt], temperature=0, max_new_tokens=50, tokenizer=tokenizer)[0]
        # Extract only the generated response after the prompt.
        det_response = det_output[len(prompt):].strip() if det_output.startswith(prompt) else det_output.strip()
        current_result["DeterministicResponse"] = det_response
        current_result["DeterministicCorrect"] = is_correct(det_response, expected_answer)

        # Run sampling (T=0.5): duplicate the prompt num_samples times.
        sample_prompts = [prompt] * num_samples
        sampled_outputs = run_model_batch(sample_prompts, temperature=0.5, max_new_tokens=50, tokenizer=tokenizer)
        # Extract the generated text after the prompt for each sample.
        sampled_responses = [ (out[len(prompt):].strip() if out.startswith(prompt) else out.strip()) for out in sampled_outputs ]
        current_result["SampledResponses"] = sampled_responses

        # Calculate sampling accuracy.
        sample_correct = sum(is_correct(resp, expected_answer) for resp in sampled_responses)
        sampled_accuracy = sample_correct / num_samples
        current_result["SampledCorrectCount"] = sample_correct
        current_result["SampledAccuracy"] = sampled_accuracy

        experiment_results.append(current_result)
        print(f"Processed: {question[:50]}... Offset {offset}")

print(f"Completed experiments for {len(sampled_questions)} QA pairs over selected offsets.")
# Out:
# Processed: In which year did the asteroid 2008 TC3 enter Eart... Offset 200
# Processed: In which year did the asteroid 2008 TC3 enter Eart... Offset 300
# Processed: In which year did the asteroid 2008 TC3 enter Eart... Offset 400
# Processed: In which year did the asteroid 2008 TC3 enter Eart... Offset 500
# Processed: In which year was the Hutch Award created to honor... Offset 200
# Processed: In which year was the Hutch Award created to honor... Offset 300
# Processed: In which year was the Hutch Award created to honor... Offset 400
# Processed: In which year was the Hutch Award created to honor... Offset 500
# Processed: In which year did the television pilot and series ... Offset 200
# Processed: In which year did the television pilot and series ... Offset 300
# Processed: In which year did the television pilot and series ... Offset 400
# Processed: In which year did the television pilot and series ... Offset 500
# Processed: In which year was Aisin AW, formerly known as Aisi... Offset 200
# Processed: In which year was Aisin AW, formerly known as Aisi... Offset 300
# Processed: In which year was Aisin AW, formerly known as Aisi... Offset 400
# Processed: In which year was Aisin AW, formerly known as Aisi... Offset 500
# Processed: In which year did the First Leg of the 2018–19 Cur... Offset 200
# Processed: In which year did the First Leg of the 2018–19 Cur... Offset 300
# Processed: In which year did the First Leg of the 2018–19 Cur... Offset 400
# Processed: In which year did the First Leg of the 2018–19 Cur... Offset 500
# Processed: In which year was the Canadian horror film 'The Pi... Offset 200
# Processed: In which year was the Canadian horror film 'The Pi... Offset 300
# Processed: In which year was the Canadian horror film 'The Pi... Offset 400
# Processed: In which year was the Canadian horror film 'The Pi... Offset 500
# Processed: In which year was the Eiffel Tower replica in Pari... Offset 200
# Processed: In which year was the Eiffel Tower replica in Pari... Offset 300
# Processed: In which year was the Eiffel Tower replica in Pari... Offset 400
# Processed: In which year was the Eiffel Tower replica in Pari... Offset 500
# Processed: In which year was the Original Farmers Market at 3... Offset 200
# Processed: In which year was the Original Farmers Market at 3... Offset 300
# Processed: In which year was the Original Farmers Market at 3... Offset 400
# Processed: In which year was the Original Farmers Market at 3... Offset 500
# Processed: In which year did the Dutch establish control over... Offset 200
# Processed: In which year did the Dutch establish control over... Offset 300
# Processed: In which year did the Dutch establish control over... Offset 400
# Processed: In which year did the Dutch establish control over... Offset 500
# Processed: In which year was Fat Joe's first solo album 'Repr... Offset 200
# Processed: In which year was Fat Joe's first solo album 'Repr... Offset 300
# Processed: In which year was Fat Joe's first solo album 'Repr... Offset 400
# Processed: In which year was Fat Joe's first solo album 'Repr... Offset 500
# Processed: In which year was Kari Jobe's album 'Where I Find ... Offset 200
# Processed: In which year was Kari Jobe's album 'Where I Find ... Offset 300
# Processed: In which year was Kari Jobe's album 'Where I Find ... Offset 400
# Processed: In which year was Kari Jobe's album 'Where I Find ... Offset 500
# Processed: In which year was Joan Ambrosio Dalza's lute colle... Offset 200
# Processed: In which year was Joan Ambrosio Dalza's lute colle... Offset 300
# Processed: In which year was Joan Ambrosio Dalza's lute colle... Offset 400
# Processed: In which year was Joan Ambrosio Dalza's lute colle... Offset 500
# Processed: In which year was the Warner Bros. Merrie Melodies... Offset 200
# Processed: In which year was the Warner Bros. Merrie Melodies... Offset 300
# Processed: In which year was the Warner Bros. Merrie Melodies... Offset 400
# Processed: In which year was the Warner Bros. Merrie Melodies... Offset 500
# Processed: In which year did Graham Greene write a review for... Offset 200
# Processed: In which year did Graham Greene write a review for... Offset 300
# Processed: In which year did Graham Greene write a review for... Offset 400
# Processed: In which year did Graham Greene write a review for... Offset 500
# Processed: In which year did the first Star Wars film, which ... Offset 200
# Processed: In which year did the first Star Wars film, which ... Offset 300
# Processed: In which year did the first Star Wars film, which ... Offset 400
# Processed: In which year did the first Star Wars film, which ... Offset 500
# Processed: In which year did Marsha Norman win the Pulitzer P... Offset 200
# Processed: In which year did Marsha Norman win the Pulitzer P... Offset 300
# Processed: In which year did Marsha Norman win the Pulitzer P... Offset 400
# Processed: In which year did Marsha Norman win the Pulitzer P... Offset 500
# Processed: In which year did the Grateful Dead's Jerry Garcia... Offset 200
# Processed: In which year did the Grateful Dead's Jerry Garcia... Offset 300
# Processed: In which year did the Grateful Dead's Jerry Garcia... Offset 400
# Processed: In which year did the Grateful Dead's Jerry Garcia... Offset 500
# Processed: In which year was the city of Hanko founded?... Offset 200
# Processed: In which year was the city of Hanko founded?... Offset 300
# Processed: In which year was the city of Hanko founded?... Offset 400
# Processed: In which year was the city of Hanko founded?... Offset 500
# Processed: In which year was the film 'My Friend Irma Goes We... Offset 200
# Processed: In which year was the film 'My Friend Irma Goes We... Offset 300
# Processed: In which year was the film 'My Friend Irma Goes We... Offset 400
# Processed: In which year was the film 'My Friend Irma Goes We... Offset 500
# Processed: In which year was Iain Banks's final novel, The Qu... Offset 200
# Processed: In which year was Iain Banks's final novel, The Qu... Offset 300
# Processed: In which year was Iain Banks's final novel, The Qu... Offset 400
# Processed: In which year was Iain Banks's final novel, The Qu... Offset 500
# Processed: In which year did the television series Mad Men pr... Offset 200
# Processed: In which year did the television series Mad Men pr... Offset 300
# Processed: In which year did the television series Mad Men pr... Offset 400
# Processed: In which year did the television series Mad Men pr... Offset 500
# Processed: In which year was the comic book 'Outcast' by Kirk... Offset 200
# Processed: In which year was the comic book 'Outcast' by Kirk... Offset 300
# Processed: In which year was the comic book 'Outcast' by Kirk... Offset 400
# Processed: In which year was the comic book 'Outcast' by Kirk... Offset 500
# Processed: In which year was Austrian copper etcher Jacob Ada... Offset 200
# Processed: In which year was Austrian copper etcher Jacob Ada... Offset 300
# Processed: In which year was Austrian copper etcher Jacob Ada... Offset 400
# Processed: In which year was Austrian copper etcher Jacob Ada... Offset 500
# Processed: In which year did the Santa Fe Railway cease all p... Offset 200
# Processed: In which year did the Santa Fe Railway cease all p... Offset 300
# Processed: In which year did the Santa Fe Railway cease all p... Offset 400
# Processed: In which year did the Santa Fe Railway cease all p... Offset 500
# Processed: In which year was the International Criminal Court... Offset 200
# Processed: In which year was the International Criminal Court... Offset 300
# Processed: In which year was the International Criminal Court... Offset 400
# Processed: In which year was the International Criminal Court... Offset 500
# Processed: In which year was Michigan's 72nd House of Represe... Offset 200
# Processed: In which year was Michigan's 72nd House of Represe... Offset 300
# Processed: In which year was Michigan's 72nd House of Represe... Offset 400
# Processed: In which year was Michigan's 72nd House of Represe... Offset 500
# Processed: In which year did Giulio Caccini publish his colle... Offset 200
# Processed: In which year did Giulio Caccini publish his colle... Offset 300
# Processed: In which year did Giulio Caccini publish his colle... Offset 400
# Processed: In which year did Giulio Caccini publish his colle... Offset 500
# Processed: In which year did the superhero feature 'Alias the... Offset 200
# Processed: In which year did the superhero feature 'Alias the... Offset 300
# Processed: In which year did the superhero feature 'Alias the... Offset 400
# Processed: In which year did the superhero feature 'Alias the... Offset 500
# Processed: In which year was the film 'Marguerite' released?... Offset 200
# Processed: In which year was the film 'Marguerite' released?... Offset 300
# Processed: In which year was the film 'Marguerite' released?... Offset 400
# Processed: In which year was the film 'Marguerite' released?... Offset 500
# Processed: In which year was Ozzy Osbourne's album 'Scream' r... Offset 200
# Processed: In which year was Ozzy Osbourne's album 'Scream' r... Offset 300
# Processed: In which year was Ozzy Osbourne's album 'Scream' r... Offset 400
# Processed: In which year was Ozzy Osbourne's album 'Scream' r... Offset 500
# Processed: In which year did the documentary film 'Burning th... Offset 200
# Processed: In which year did the documentary film 'Burning th... Offset 300
# Processed: In which year did the documentary film 'Burning th... Offset 400
# Processed: In which year did the documentary film 'Burning th... Offset 500
# Processed: In which year was the Wolfchase Galleria shopping ... Offset 200
# Processed: In which year was the Wolfchase Galleria shopping ... Offset 300
# Processed: In which year was the Wolfchase Galleria shopping ... Offset 400
# Processed: In which year was the Wolfchase Galleria shopping ... Offset 500
# Processed: In which year was Vince Taylor, the British singer... Offset 200
# Processed: In which year was Vince Taylor, the British singer... Offset 300
# Processed: In which year was Vince Taylor, the British singer... Offset 400
# Processed: In which year was Vince Taylor, the British singer... Offset 500
# Processed: In which year were the Welsh 0-6-2T locomotives ta... Offset 200
# Processed: In which year were the Welsh 0-6-2T locomotives ta... Offset 300
# Processed: In which year were the Welsh 0-6-2T locomotives ta... Offset 400
# Processed: In which year were the Welsh 0-6-2T locomotives ta... Offset 500
# Processed: In which year was the American women's wear brand ... Offset 200
# Processed: In which year was the American women's wear brand ... Offset 300
# Processed: In which year was the American women's wear brand ... Offset 400
# Processed: In which year was the American women's wear brand ... Offset 500
# Processed: In which year was the elliptical galaxy NGC 4066 d... Offset 200
# Processed: In which year was the elliptical galaxy NGC 4066 d... Offset 300
# Processed: In which year was the elliptical galaxy NGC 4066 d... Offset 400
# Processed: In which year was the elliptical galaxy NGC 4066 d... Offset 500
# Processed: In which year was the South Korean television seri... Offset 200
# Processed: In which year was the South Korean television seri... Offset 300
# Processed: In which year was the South Korean television seri... Offset 400
# Processed: In which year was the South Korean television seri... Offset 500
# Processed: In which year did Alexei Navalny return to Russia ... Offset 200
# Processed: In which year did Alexei Navalny return to Russia ... Offset 300
# Processed: In which year did Alexei Navalny return to Russia ... Offset 400
# Processed: In which year did Alexei Navalny return to Russia ... Offset 500
# Processed: In which year was the Yamaha Tenori-on launched in... Offset 200
# Processed: In which year was the Yamaha Tenori-on launched in... Offset 300
# Processed: In which year was the Yamaha Tenori-on launched in... Offset 400
# Processed: In which year was the Yamaha Tenori-on launched in... Offset 500
# Processed: In which year was the Veterans Appeals Improvement... Offset 200
# Processed: In which year was the Veterans Appeals Improvement... Offset 300
# Processed: In which year was the Veterans Appeals Improvement... Offset 400
# Processed: In which year was the Veterans Appeals Improvement... Offset 500
# Processed: In which year was the album 'Hideout' by Film Scho... Offset 200
# Processed: In which year was the album 'Hideout' by Film Scho... Offset 300
# Processed: In which year was the album 'Hideout' by Film Scho... Offset 400
# Processed: In which year was the album 'Hideout' by Film Scho... Offset 500
# Processed: In which year was the Nishat Bagh garden designed ... Offset 200
# Processed: In which year was the Nishat Bagh garden designed ... Offset 300
# Processed: In which year was the Nishat Bagh garden designed ... Offset 400
# Processed: In which year was the Nishat Bagh garden designed ... Offset 500
# Processed: In which year did King Crimson release the live th... Offset 200
# Processed: In which year did King Crimson release the live th... Offset 300
# Processed: In which year did King Crimson release the live th... Offset 400
# Processed: In which year did King Crimson release the live th... Offset 500
# Processed: In which year was the Military College of Signals ... Offset 200
# Processed: In which year was the Military College of Signals ... Offset 300
# Processed: In which year was the Military College of Signals ... Offset 400
# Processed: In which year was the Military College of Signals ... Offset 500
# Processed: In which year was Elton John's song 'Crocodile Roc... Offset 200
# Processed: In which year was Elton John's song 'Crocodile Roc... Offset 300
# Processed: In which year was Elton John's song 'Crocodile Roc... Offset 400
# Processed: In which year was Elton John's song 'Crocodile Roc... Offset 500
# Processed: In which year did the siege of Perekop, a battle o... Offset 200
# Processed: In which year did the siege of Perekop, a battle o... Offset 300
# Processed: In which year did the siege of Perekop, a battle o... Offset 400
# Processed: In which year did the siege of Perekop, a battle o... Offset 500
# Processed: In which year was Viktor Knorre, the Russian astro... Offset 200
# Processed: In which year was Viktor Knorre, the Russian astro... Offset 300
# Processed: In which year was Viktor Knorre, the Russian astro... Offset 400
# Processed: In which year was Viktor Knorre, the Russian astro... Offset 500
# Processed: In which year was the Japanese visual kei rock ban... Offset 200
# Processed: In which year was the Japanese visual kei rock ban... Offset 300
# Processed: In which year was the Japanese visual kei rock ban... Offset 400
# Processed: In which year was the Japanese visual kei rock ban... Offset 500
# Processed: In which year was the Ljubljana Summer Festival es... Offset 200
# Processed: In which year was the Ljubljana Summer Festival es... Offset 300
# Processed: In which year was the Ljubljana Summer Festival es... Offset 400
# Processed: In which year was the Ljubljana Summer Festival es... Offset 500
# Processed: In which year was the documentary film 'Pond Hocke... Offset 200
# Processed: In which year was the documentary film 'Pond Hocke... Offset 300
# Processed: In which year was the documentary film 'Pond Hocke... Offset 400
# Processed: In which year was the documentary film 'Pond Hocke... Offset 500
# Processed: In which year did Thomas Croft Neibaur receive the... Offset 200
# Processed: In which year did Thomas Croft Neibaur receive the... Offset 300
# Processed: In which year did Thomas Croft Neibaur receive the... Offset 400
# Processed: In which year did Thomas Croft Neibaur receive the... Offset 500
# Processed: In which year did Lee Chih-feng compete in the men... Offset 200
# Processed: In which year did Lee Chih-feng compete in the men... Offset 300
# Processed: In which year did Lee Chih-feng compete in the men... Offset 400
# Processed: In which year did Lee Chih-feng compete in the men... Offset 500
# Processed: In which year did a sample of chalk sites in Engla... Offset 200
# Processed: In which year did a sample of chalk sites in Engla... Offset 300
# Processed: In which year did a sample of chalk sites in Engla... Offset 400
# Processed: In which year did a sample of chalk sites in Engla... Offset 500
# Processed: In which year did the television programme Asian M... Offset 200
# Processed: In which year did the television programme Asian M... Offset 300
# Processed: In which year did the television programme Asian M... Offset 400
# Processed: In which year did the television programme Asian M... Offset 500
# Processed: In which year was former Australian rules football... Offset 200
# Processed: In which year was former Australian rules football... Offset 300
# Processed: In which year was former Australian rules football... Offset 400
# Processed: In which year was former Australian rules football... Offset 500
# Processed: In which year did Biyan Wanaatmadja establish his ... Offset 200
# Processed: In which year did Biyan Wanaatmadja establish his ... Offset 300
# Processed: In which year did Biyan Wanaatmadja establish his ... Offset 400
# Processed: In which year did Biyan Wanaatmadja establish his ... Offset 500
# Processed: In which year did George P. Stiles begin his trave... Offset 200
# Processed: In which year did George P. Stiles begin his trave... Offset 300
# Processed: In which year did George P. Stiles begin his trave... Offset 400
# Processed: In which year did George P. Stiles begin his trave... Offset 500
# Processed: In which year was the Giornate degli Autori, an in... Offset 200
# Processed: In which year was the Giornate degli Autori, an in... Offset 300
# Processed: In which year was the Giornate degli Autori, an in... Offset 400
# Processed: In which year was the Giornate degli Autori, an in... Offset 500
# Processed: In which year was the current Pont de Sully bridge... Offset 200
# Processed: In which year was the current Pont de Sully bridge... Offset 300
# Processed: In which year was the current Pont de Sully bridge... Offset 400
# Processed: In which year was the current Pont de Sully bridge... Offset 500
# Processed: In which year did Berta Loran and her family immig... Offset 200
# Processed: In which year did Berta Loran and her family immig... Offset 300
# Processed: In which year did Berta Loran and her family immig... Offset 400
# Processed: In which year did Berta Loran and her family immig... Offset 500
# Processed: In which year was Craig Charron drafted by the Mon... Offset 200
# Processed: In which year was Craig Charron drafted by the Mon... Offset 300
# Processed: In which year was Craig Charron drafted by the Mon... Offset 400
# Processed: In which year was Craig Charron drafted by the Mon... Offset 500
# Processed: In which year did Gonzalo Nápoli Soria make his pr... Offset 200
# Processed: In which year did Gonzalo Nápoli Soria make his pr... Offset 300
# Processed: In which year did Gonzalo Nápoli Soria make his pr... Offset 400
# Processed: In which year did Gonzalo Nápoli Soria make his pr... Offset 500
# Processed: In which year was Horace Wilson, the American prof... Offset 200
# Processed: In which year was Horace Wilson, the American prof... Offset 300
# Processed: In which year was Horace Wilson, the American prof... Offset 400
# Processed: In which year was Horace Wilson, the American prof... Offset 500
# Processed: In which year was Mohsen Rohami born?... Offset 200
# Processed: In which year was Mohsen Rohami born?... Offset 300
# Processed: In which year was Mohsen Rohami born?... Offset 400
# Processed: In which year was Mohsen Rohami born?... Offset 500
# Processed: In which year was William Amos Smith posthumously ... Offset 200
# Processed: In which year was William Amos Smith posthumously ... Offset 300
# Processed: In which year was William Amos Smith posthumously ... Offset 400
# Processed: In which year was William Amos Smith posthumously ... Offset 500
# Processed: In which year did the Lambourn Valley Railway line... Offset 200
# Processed: In which year did the Lambourn Valley Railway line... Offset 300
# Processed: In which year did the Lambourn Valley Railway line... Offset 400
# Processed: In which year did the Lambourn Valley Railway line... Offset 500
# Processed: In which year was former South African cricketer C... Offset 200
# Processed: In which year was former South African cricketer C... Offset 300
# Processed: In which year was former South African cricketer C... Offset 400
# Processed: In which year was former South African cricketer C... Offset 500
# Processed: In which year was Kim Myong-gum, the North Korean ... Offset 200
# Processed: In which year was Kim Myong-gum, the North Korean ... Offset 300
# Processed: In which year was Kim Myong-gum, the North Korean ... Offset 400
# Processed: In which year was Kim Myong-gum, the North Korean ... Offset 500
# Processed: In which year did Nripatindravarman II's reign in ... Offset 200
# Processed: In which year did Nripatindravarman II's reign in ... Offset 300
# Processed: In which year did Nripatindravarman II's reign in ... Offset 400
# Processed: In which year did Nripatindravarman II's reign in ... Offset 500
# Processed: In which year was the Slovak Government Flight Ser... Offset 200
# Processed: In which year was the Slovak Government Flight Ser... Offset 300
# Processed: In which year was the Slovak Government Flight Ser... Offset 400
# Processed: In which year was the Slovak Government Flight Ser... Offset 500
# Processed: In which year did the Bristol Theseus become the f... Offset 200
# Processed: In which year did the Bristol Theseus become the f... Offset 300
# Processed: In which year did the Bristol Theseus become the f... Offset 400
# Processed: In which year did the Bristol Theseus become the f... Offset 500
# Processed: In which year was Ray 'Pinky' Velazquez born?... Offset 200
# Processed: In which year was Ray 'Pinky' Velazquez born?... Offset 300
# Processed: In which year was Ray 'Pinky' Velazquez born?... Offset 400
# Processed: In which year was Ray 'Pinky' Velazquez born?... Offset 500
# Processed: In which year did Alfred Hefter found the French-l... Offset 200
# Processed: In which year did Alfred Hefter found the French-l... Offset 300
# Processed: In which year did Alfred Hefter found the French-l... Offset 400
# Processed: In which year did Alfred Hefter found the French-l... Offset 500
# Processed: In which year did Mohamed Lamine Yattara make his ... Offset 200
# Processed: In which year did Mohamed Lamine Yattara make his ... Offset 300
# Processed: In which year did Mohamed Lamine Yattara make his ... Offset 400
# Processed: In which year did Mohamed Lamine Yattara make his ... Offset 500
# Processed: In which year was the beetle species Lignyodes var... Offset 200
# Processed: In which year was the beetle species Lignyodes var... Offset 300
# Processed: In which year was the beetle species Lignyodes var... Offset 400
# Processed: In which year was the beetle species Lignyodes var... Offset 500
# Processed: In which year did the Royal Australian Air Force r... Offset 200
# Processed: In which year did the Royal Australian Air Force r... Offset 300
# Processed: In which year did the Royal Australian Air Force r... Offset 400
# Processed: In which year did the Royal Australian Air Force r... Offset 500
# Processed: In which year did Tate Ratledge commit to play col... Offset 200
# Processed: In which year did Tate Ratledge commit to play col... Offset 300
# Processed: In which year did Tate Ratledge commit to play col... Offset 400
# Processed: In which year did Tate Ratledge commit to play col... Offset 500
# Processed: In which year was the Constitution of Guinea-Bissa... Offset 200
# Processed: In which year was the Constitution of Guinea-Bissa... Offset 300
# Processed: In which year was the Constitution of Guinea-Bissa... Offset 400
# Processed: In which year was the Constitution of Guinea-Bissa... Offset 500
# Processed: In which year were the nerve agents at Site 59 in ... Offset 200
# Processed: In which year were the nerve agents at Site 59 in ... Offset 300
# Processed: In which year were the nerve agents at Site 59 in ... Offset 400
# Processed: In which year were the nerve agents at Site 59 in ... Offset 500
# Processed: In which year was Picfair officially launched as a... Offset 200
# Processed: In which year was Picfair officially launched as a... Offset 300
# Processed: In which year was Picfair officially launched as a... Offset 400
# Processed: In which year was Picfair officially launched as a... Offset 500
# Processed: In which year did Chad Lunsford graduate from Geor... Offset 200
# Processed: In which year did Chad Lunsford graduate from Geor... Offset 300
# Processed: In which year did Chad Lunsford graduate from Geor... Offset 400
# Processed: In which year did Chad Lunsford graduate from Geor... Offset 500
# Processed: In which year did David Foster sign a deal with Wa... Offset 200
# Processed: In which year did David Foster sign a deal with Wa... Offset 300
# Processed: In which year did David Foster sign a deal with Wa... Offset 400
# Processed: In which year did David Foster sign a deal with Wa... Offset 500
# Processed: In which year were vehicles powered solely by petr... Offset 200
# Processed: In which year were vehicles powered solely by petr... Offset 300
# Processed: In which year were vehicles powered solely by petr... Offset 400
# Processed: In which year were vehicles powered solely by petr... Offset 500
# Processed: In which year was the Captain Forbes House Museum ... Offset 200
# Processed: In which year was the Captain Forbes House Museum ... Offset 300
# Processed: In which year was the Captain Forbes House Museum ... Offset 400
# Processed: In which year was the Captain Forbes House Museum ... Offset 500
# Processed: In which year was Daiwa Securities SB Capital Mark... Offset 200
# Processed: In which year was Daiwa Securities SB Capital Mark... Offset 300
# Processed: In which year was Daiwa Securities SB Capital Mark... Offset 400
# Processed: In which year was Daiwa Securities SB Capital Mark... Offset 500
# Processed: In which year was Tim McManigal signed by the Winn... Offset 200
# Processed: In which year was Tim McManigal signed by the Winn... Offset 300
# Processed: In which year was Tim McManigal signed by the Winn... Offset 400
# Processed: In which year was Tim McManigal signed by the Winn... Offset 500
# Processed: In which year was the present church of St. Michel... Offset 200
# Processed: In which year was the present church of St. Michel... Offset 300
# Processed: In which year was the present church of St. Michel... Offset 400
# Processed: In which year was the present church of St. Michel... Offset 500
# Processed: In which year was Raja Club Athletic founded in Ca... Offset 200
# Processed: In which year was Raja Club Athletic founded in Ca... Offset 300
# Processed: In which year was Raja Club Athletic founded in Ca... Offset 400
# Processed: In which year was Raja Club Athletic founded in Ca... Offset 500
# Processed: In which year was the Mandelholz Dam completed?... Offset 200
# Processed: In which year was the Mandelholz Dam completed?... Offset 300
# Processed: In which year was the Mandelholz Dam completed?... Offset 400
# Processed: In which year was the Mandelholz Dam completed?... Offset 500
# Processed: In which year did Thomas Cocklyn accept a royal pa... Offset 200
# Processed: In which year did Thomas Cocklyn accept a royal pa... Offset 300
# Processed: In which year did Thomas Cocklyn accept a royal pa... Offset 400
# Processed: In which year did Thomas Cocklyn accept a royal pa... Offset 500
# Processed: In which year did Croatia participate in the Eurov... Offset 200
# Processed: In which year did Croatia participate in the Eurov... Offset 300
# Processed: In which year did Croatia participate in the Eurov... Offset 400
# Processed: In which year did Croatia participate in the Eurov... Offset 500
# Processed: In which year was the graphic novel 'The Festering... Offset 200
# Processed: In which year was the graphic novel 'The Festering... Offset 300
# Processed: In which year was the graphic novel 'The Festering... Offset 400
# Processed: In which year was the graphic novel 'The Festering... Offset 500
# Processed: In which year was the National Hellenic Museum's n... Offset 200
# Processed: In which year was the National Hellenic Museum's n... Offset 300
# Processed: In which year was the National Hellenic Museum's n... Offset 400
# Processed: In which year was the National Hellenic Museum's n... Offset 500
# Processed: In which year was the Euro 4000 demonstrator locom... Offset 200
# Processed: In which year was the Euro 4000 demonstrator locom... Offset 300
# Processed: In which year was the Euro 4000 demonstrator locom... Offset 400
# Processed: In which year was the Euro 4000 demonstrator locom... Offset 500
# Processed: In which year was Sidney Godolphin, 1st Earl of Go... Offset 200
# Processed: In which year was Sidney Godolphin, 1st Earl of Go... Offset 300
# Processed: In which year was Sidney Godolphin, 1st Earl of Go... Offset 400
# Processed: In which year was Sidney Godolphin, 1st Earl of Go... Offset 500
# Processed: In which year was the species Parotocinclus halbot... Offset 200
# Processed: In which year was the species Parotocinclus halbot... Offset 300
# Processed: In which year was the species Parotocinclus halbot... Offset 400
# Processed: In which year was the species Parotocinclus halbot... Offset 500
# Processed: In which year was The Anatomical Record journal es... Offset 200
# Processed: In which year was The Anatomical Record journal es... Offset 300
# Processed: In which year was The Anatomical Record journal es... Offset 400
# Processed: In which year was The Anatomical Record journal es... Offset 500
# Processed: In which year did Keanan Duffty relocate to New Yo... Offset 200
# Processed: In which year did Keanan Duffty relocate to New Yo... Offset 300
# Processed: In which year did Keanan Duffty relocate to New Yo... Offset 400
# Processed: In which year did Keanan Duffty relocate to New Yo... Offset 500
# Processed: In which year was the Queen's Own Mercian Yeomanry... Offset 200
# Processed: In which year was the Queen's Own Mercian Yeomanry... Offset 300
# Processed: In which year was the Queen's Own Mercian Yeomanry... Offset 400
# Processed: In which year was the Queen's Own Mercian Yeomanry... Offset 500
# Processed: In which year was the Indian Kannada film Belli Na... Offset 200
# Processed: In which year was the Indian Kannada film Belli Na... Offset 300
# Processed: In which year was the Indian Kannada film Belli Na... Offset 400
# Processed: In which year was the Indian Kannada film Belli Na... Offset 500
# Processed: In which year was Józef Paczyński transported to A... Offset 200
# Processed: In which year was Józef Paczyński transported to A... Offset 300
# Processed: In which year was Józef Paczyński transported to A... Offset 400
# Processed: In which year was Józef Paczyński transported to A... Offset 500
# Processed: In which year did Jacques Potgieter become a Sprin... Offset 200
# Processed: In which year did Jacques Potgieter become a Sprin... Offset 300
# Processed: In which year did Jacques Potgieter become a Sprin... Offset 400
# Processed: In which year did Jacques Potgieter become a Sprin... Offset 500
# Processed: In which year was the ship Vittoria launched at Wh... Offset 200
# Processed: In which year was the ship Vittoria launched at Wh... Offset 300
# Processed: In which year was the ship Vittoria launched at Wh... Offset 400
# Processed: In which year was the ship Vittoria launched at Wh... Offset 500
# Processed: In which year was the Perugia Ponte San Giovanni r... Offset 200
# Processed: In which year was the Perugia Ponte San Giovanni r... Offset 300
# Processed: In which year was the Perugia Ponte San Giovanni r... Offset 400
# Processed: In which year was the Perugia Ponte San Giovanni r... Offset 500
# Processed: In which year did Ira Ellis McMillian propose to R... Offset 200
# Processed: In which year did Ira Ellis McMillian propose to R... Offset 300
# Processed: In which year did Ira Ellis McMillian propose to R... Offset 400
# Processed: In which year did Ira Ellis McMillian propose to R... Offset 500
# Processed: In which year did the Ole Miss Rebels baseball tea... Offset 200
# Processed: In which year did the Ole Miss Rebels baseball tea... Offset 300
# Processed: In which year did the Ole Miss Rebels baseball tea... Offset 400
# Processed: In which year did the Ole Miss Rebels baseball tea... Offset 500
# Processed: In which year was the Wagakki Band's second live v... Offset 200
# Processed: In which year was the Wagakki Band's second live v... Offset 300
# Processed: In which year was the Wagakki Band's second live v... Offset 400
# Processed: In which year was the Wagakki Band's second live v... Offset 500
# Processed: In which year was Charles Munch, the orchestral co... Offset 200
# Processed: In which year was Charles Munch, the orchestral co... Offset 300
# Processed: In which year was Charles Munch, the orchestral co... Offset 400
# Processed: In which year was Charles Munch, the orchestral co... Offset 500
# Processed: In which year was the moth species Miyakea zhengi ... Offset 200
# Processed: In which year was the moth species Miyakea zhengi ... Offset 300
# Processed: In which year was the moth species Miyakea zhengi ... Offset 400
# Processed: In which year was the moth species Miyakea zhengi ... Offset 500
# Processed: In which year was the Australian hard rock band Ma... Offset 200
# Processed: In which year was the Australian hard rock band Ma... Offset 300
# Processed: In which year was the Australian hard rock band Ma... Offset 400
# Processed: In which year was the Australian hard rock band Ma... Offset 500
# Processed: In which year was William Shakespeare's play 'Henr... Offset 200
# Processed: In which year was William Shakespeare's play 'Henr... Offset 300
# Processed: In which year was William Shakespeare's play 'Henr... Offset 400
# Processed: In which year was William Shakespeare's play 'Henr... Offset 500
# Processed: In which year was the total population of Gmina Ra... Offset 200
# Processed: In which year was the total population of Gmina Ra... Offset 300
# Processed: In which year was the total population of Gmina Ra... Offset 400
# Processed: In which year was the total population of Gmina Ra... Offset 500
# Processed: In which year did Elle Duncan join SportsCenter as... Offset 200
# Processed: In which year did Elle Duncan join SportsCenter as... Offset 300
# Processed: In which year did Elle Duncan join SportsCenter as... Offset 400
# Processed: In which year did Elle Duncan join SportsCenter as... Offset 500
# Processed: In which year did Group C of the FIFA Women's Worl... Offset 200
# Processed: In which year did Group C of the FIFA Women's Worl... Offset 300
# Processed: In which year did Group C of the FIFA Women's Worl... Offset 400
# Processed: In which year did Group C of the FIFA Women's Worl... Offset 500
# Processed: In which year was the 41st Infantry Division of th... Offset 200
# Processed: In which year was the 41st Infantry Division of th... Offset 300
# Processed: In which year was the 41st Infantry Division of th... Offset 400
# Processed: In which year was the 41st Infantry Division of th... Offset 500
# Processed: In which year was the song 'Baila Baila Baila' by ... Offset 200
# Processed: In which year was the song 'Baila Baila Baila' by ... Offset 300
# Processed: In which year was the song 'Baila Baila Baila' by ... Offset 400
# Processed: In which year was the song 'Baila Baila Baila' by ... Offset 500
# Processed: In which year did Graham Linehan's marriage to Hel... Offset 200
# Processed: In which year did Graham Linehan's marriage to Hel... Offset 300
# Processed: In which year did Graham Linehan's marriage to Hel... Offset 400
# Processed: In which year did Graham Linehan's marriage to Hel... Offset 500
# Processed: In which year was the military gaol, now housing t... Offset 200
# Processed: In which year was the military gaol, now housing t... Offset 300
# Processed: In which year was the military gaol, now housing t... Offset 400
# Processed: In which year was the military gaol, now housing t... Offset 500
# Processed: In which year did MGM announce the film 'Killer Mc... Offset 200
# Processed: In which year did MGM announce the film 'Killer Mc... Offset 300
# Processed: In which year did MGM announce the film 'Killer Mc... Offset 400
# Processed: In which year did MGM announce the film 'Killer Mc... Offset 500
# Processed: In which year was the Mexican western film 'Los mu... Offset 200
# Processed: In which year was the Mexican western film 'Los mu... Offset 300
# Processed: In which year was the Mexican western film 'Los mu... Offset 400
# Processed: In which year was the Mexican western film 'Los mu... Offset 500
# Processed: In which year was the remix album 'Los Vaqueros: W... Offset 200
# Processed: In which year was the remix album 'Los Vaqueros: W... Offset 300
# Processed: In which year was the remix album 'Los Vaqueros: W... Offset 400
# Processed: In which year was the remix album 'Los Vaqueros: W... Offset 500
# Processed: In which year was the type genus of the family End... Offset 200
# Processed: In which year was the type genus of the family End... Offset 300
# Processed: In which year was the type genus of the family End... Offset 400
# Processed: In which year was the type genus of the family End... Offset 500
# Processed: In which year did Disney acquire ownership of Saba... Offset 200
# Processed: In which year did Disney acquire ownership of Saba... Offset 300
# Processed: In which year did Disney acquire ownership of Saba... Offset 400
# Processed: In which year did Disney acquire ownership of Saba... Offset 500
# Processed: In which year did Michael Weatherly make his direc... Offset 200
# Processed: In which year did Michael Weatherly make his direc... Offset 300
# Processed: In which year did Michael Weatherly make his direc... Offset 400
# Processed: In which year did Michael Weatherly make his direc... Offset 500
# Processed: In which year was the species Nesioneta elegans de... Offset 200
# Processed: In which year was the species Nesioneta elegans de... Offset 300
# Processed: In which year was the species Nesioneta elegans de... Offset 400
# Processed: In which year was the species Nesioneta elegans de... Offset 500
# Processed: In which year was the tactical shooter video game ... Offset 200
# Processed: In which year was the tactical shooter video game ... Offset 300
# Processed: In which year was the tactical shooter video game ... Offset 400
# Processed: In which year was the tactical shooter video game ... Offset 500
# Processed: In which year was the orphan salamander (Bolitoglo... Offset 200
# Processed: In which year was the orphan salamander (Bolitoglo... Offset 300
# Processed: In which year was the orphan salamander (Bolitoglo... Offset 400
# Processed: In which year was the orphan salamander (Bolitoglo... Offset 500
# Processed: In which year did Carlos Marcello become the crime... Offset 200
# Processed: In which year did Carlos Marcello become the crime... Offset 300
# Processed: In which year did Carlos Marcello become the crime... Offset 400
# Processed: In which year did Carlos Marcello become the crime... Offset 500
# Processed: In which year did Daniel Pomarède complete his Ph.... Offset 200
# Processed: In which year did Daniel Pomarède complete his Ph.... Offset 300
# Processed: In which year did Daniel Pomarède complete his Ph.... Offset 400
# Processed: In which year did Daniel Pomarède complete his Ph.... Offset 500
# Processed: In which year did Edvard Moser receive his PhD in ... Offset 200
# Processed: In which year did Edvard Moser receive his PhD in ... Offset 300
# Processed: In which year did Edvard Moser receive his PhD in ... Offset 400
# Processed: In which year did Edvard Moser receive his PhD in ... Offset 500
# Processed: In which year was the Lorenz beam blind-landing ra... Offset 200
# Processed: In which year was the Lorenz beam blind-landing ra... Offset 300
# Processed: In which year was the Lorenz beam blind-landing ra... Offset 400
# Processed: In which year was the Lorenz beam blind-landing ra... Offset 500
# Processed: In which year did Paul Arthur Sorg inherit $10,000... Offset 200
# Processed: In which year did Paul Arthur Sorg inherit $10,000... Offset 300
# Processed: In which year did Paul Arthur Sorg inherit $10,000... Offset 400
# Processed: In which year did Paul Arthur Sorg inherit $10,000... Offset 500
# Processed: In which year was Canadian professional ice hockey... Offset 200
# Processed: In which year was Canadian professional ice hockey... Offset 300
# Processed: In which year was Canadian professional ice hockey... Offset 400
# Processed: In which year was Canadian professional ice hockey... Offset 500
# Processed: In which year was the anime adaptation of the Japa... Offset 200
# Processed: In which year was the anime adaptation of the Japa... Offset 300
# Processed: In which year was the anime adaptation of the Japa... Offset 400
# Processed: In which year was the anime adaptation of the Japa... Offset 500
# Processed: In which year was the drug Drinabant licensed by O... Offset 200
# Processed: In which year was the drug Drinabant licensed by O... Offset 300
# Processed: In which year was the drug Drinabant licensed by O... Offset 400
# Processed: In which year was the drug Drinabant licensed by O... Offset 500
# Processed: In which year did Arvo Lamberg win the Mestaruussa... Offset 200
# Processed: In which year did Arvo Lamberg win the Mestaruussa... Offset 300
# Processed: In which year did Arvo Lamberg win the Mestaruussa... Offset 400
# Processed: In which year did Arvo Lamberg win the Mestaruussa... Offset 500
# Processed: In which year was the horse race now known as the ... Offset 200
# Processed: In which year was the horse race now known as the ... Offset 300
# Processed: In which year was the horse race now known as the ... Offset 400
# Processed: In which year was the horse race now known as the ... Offset 500
# Processed: In which year was the 43rd Rifle Division upgraded... Offset 200
# Processed: In which year was the 43rd Rifle Division upgraded... Offset 300
# Processed: In which year was the 43rd Rifle Division upgraded... Offset 400
# Processed: In which year was the 43rd Rifle Division upgraded... Offset 500
# Processed: In which year was the Denso Iris basketball team e... Offset 200
# Processed: In which year was the Denso Iris basketball team e... Offset 300
# Processed: In which year was the Denso Iris basketball team e... Offset 400
# Processed: In which year was the Denso Iris basketball team e... Offset 500
# Processed: In which year did Curtis Pendleton Smith become th... Offset 200
# Processed: In which year did Curtis Pendleton Smith become th... Offset 300
# Processed: In which year did Curtis Pendleton Smith become th... Offset 400
# Processed: In which year did Curtis Pendleton Smith become th... Offset 500
# Processed: In which year did the song 'The Winker's Song (Mis... Offset 200
# Processed: In which year did the song 'The Winker's Song (Mis... Offset 300
# Processed: In which year did the song 'The Winker's Song (Mis... Offset 400
# Processed: In which year did the song 'The Winker's Song (Mis... Offset 500
# Processed: In which year was Josh Carmichael drafted to the C... Offset 200
# Processed: In which year was Josh Carmichael drafted to the C... Offset 300
# Processed: In which year was Josh Carmichael drafted to the C... Offset 400
# Processed: In which year was Josh Carmichael drafted to the C... Offset 500
# Processed: In which year were the villages Adunați, Bucov, an... Offset 200
# Processed: In which year were the villages Adunați, Bucov, an... Offset 300
# Processed: In which year were the villages Adunați, Bucov, an... Offset 400
# Processed: In which year were the villages Adunați, Bucov, an... Offset 500
# Processed: In which year was the Professional Landcare Networ... Offset 200
# Processed: In which year was the Professional Landcare Networ... Offset 300
# Processed: In which year was the Professional Landcare Networ... Offset 400
# Processed: In which year was the Professional Landcare Networ... Offset 500
# Processed: In which year did the prototype of the Fouga Zéphy... Offset 200
# Processed: In which year did the prototype of the Fouga Zéphy... Offset 300
# Processed: In which year did the prototype of the Fouga Zéphy... Offset 400
# Processed: In which year did the prototype of the Fouga Zéphy... Offset 500
# Processed: In which year did Billy Banks record with the Rhyt... Offset 200
# Processed: In which year did Billy Banks record with the Rhyt... Offset 300
# Processed: In which year did Billy Banks record with the Rhyt... Offset 400
# Processed: In which year did Billy Banks record with the Rhyt... Offset 500
# Processed: In which year did Philip Riedesel zu Camberg enter... Offset 200
# Processed: In which year did Philip Riedesel zu Camberg enter... Offset 300
# Processed: In which year did Philip Riedesel zu Camberg enter... Offset 400
# Processed: In which year did Philip Riedesel zu Camberg enter... Offset 500
# Processed: In which year was Balthasar Guersye admitted as a ... Offset 200
# Processed: In which year was Balthasar Guersye admitted as a ... Offset 300
# Processed: In which year was Balthasar Guersye admitted as a ... Offset 400
# Processed: In which year was Balthasar Guersye admitted as a ... Offset 500
# Processed: In which year did Viola Priesemann become a fellow... Offset 200
# Processed: In which year did Viola Priesemann become a fellow... Offset 300
# Processed: In which year did Viola Priesemann become a fellow... Offset 400
# Processed: In which year did Viola Priesemann become a fellow... Offset 500
# Processed: In which year was the post office in Raeco, Washin... Offset 200
# Processed: In which year was the post office in Raeco, Washin... Offset 300
# Processed: In which year was the post office in Raeco, Washin... Offset 400
# Processed: In which year was the post office in Raeco, Washin... Offset 500
# Processed: In which year was the Soot Canal in Norway constru... Offset 200
# Processed: In which year was the Soot Canal in Norway constru... Offset 300
# Processed: In which year was the Soot Canal in Norway constru... Offset 400
# Processed: In which year was the Soot Canal in Norway constru... Offset 500
# Processed: In which year did Agnieszka Marzenna Siwek-Jechows... Offset 200
# Processed: In which year did Agnieszka Marzenna Siwek-Jechows... Offset 300
# Processed: In which year did Agnieszka Marzenna Siwek-Jechows... Offset 400
# Processed: In which year did Agnieszka Marzenna Siwek-Jechows... Offset 500
# Processed: In which year did the Burmese drama film 'Confessi... Offset 200
# Processed: In which year did the Burmese drama film 'Confessi... Offset 300
# Processed: In which year did the Burmese drama film 'Confessi... Offset 400
# Processed: In which year did the Burmese drama film 'Confessi... Offset 500
# Processed: In which year was the Amaan Stadium in Zanzibar, T... Offset 200
# Processed: In which year was the Amaan Stadium in Zanzibar, T... Offset 300
# Processed: In which year was the Amaan Stadium in Zanzibar, T... Offset 400
# Processed: In which year was the Amaan Stadium in Zanzibar, T... Offset 500
# Processed: In which year did Ali Tounsi become the Chief of A... Offset 200
# Processed: In which year did Ali Tounsi become the Chief of A... Offset 300
# Processed: In which year did Ali Tounsi become the Chief of A... Offset 400
# Processed: In which year did Ali Tounsi become the Chief of A... Offset 500
# Processed: In which year was French cinematographer Jean Tour... Offset 200
# Processed: In which year was French cinematographer Jean Tour... Offset 300
# Processed: In which year was French cinematographer Jean Tour... Offset 400
# Processed: In which year was French cinematographer Jean Tour... Offset 500
# Processed: In which year was the species Penicillium ribium d... Offset 200
# Processed: In which year was the species Penicillium ribium d... Offset 300
# Processed: In which year was the species Penicillium ribium d... Offset 400
# Processed: In which year was the species Penicillium ribium d... Offset 500
# Processed: In which year did Ekaterina Avramova decide to mov... Offset 200
# Processed: In which year did Ekaterina Avramova decide to mov... Offset 300
# Processed: In which year did Ekaterina Avramova decide to mov... Offset 400
# Processed: In which year did Ekaterina Avramova decide to mov... Offset 500
# Processed: In which year did Pedro Bravo de Acuña become the ... Offset 200
# Processed: In which year did Pedro Bravo de Acuña become the ... Offset 300
# Processed: In which year did Pedro Bravo de Acuña become the ... Offset 400
# Processed: In which year did Pedro Bravo de Acuña become the ... Offset 500
# Processed: In which year did Arunoday Mondal establish a char... Offset 200
# Processed: In which year did Arunoday Mondal establish a char... Offset 300
# Processed: In which year did Arunoday Mondal establish a char... Offset 400
# Processed: In which year did Arunoday Mondal establish a char... Offset 500
# Processed: In which year did the Aurora legend start due to i... Offset 200
# Processed: In which year did the Aurora legend start due to i... Offset 300
# Processed: In which year did the Aurora legend start due to i... Offset 400
# Processed: In which year did the Aurora legend start due to i... Offset 500
# Processed: In which year was Egyptian footballer El Sayed Sal... Offset 200
# Processed: In which year was Egyptian footballer El Sayed Sal... Offset 300
# Processed: In which year was Egyptian footballer El Sayed Sal... Offset 400
# Processed: In which year was Egyptian footballer El Sayed Sal... Offset 500
# Processed: In which year was the Directorium in publicis et c... Offset 200
# Processed: In which year was the Directorium in publicis et c... Offset 300
# Processed: In which year was the Directorium in publicis et c... Offset 400
# Processed: In which year was the Directorium in publicis et c... Offset 500
# Processed: In which year was Donald Nelson Rhodes born?... Offset 200
# Processed: In which year was Donald Nelson Rhodes born?... Offset 300
# Processed: In which year was Donald Nelson Rhodes born?... Offset 400
# Processed: In which year was Donald Nelson Rhodes born?... Offset 500
# Processed: In which year did André Menez become the president... Offset 200
# Processed: In which year did André Menez become the president... Offset 300
# Processed: In which year did André Menez become the president... Offset 400
# Processed: In which year did André Menez become the president... Offset 500
# Processed: In which year was the film 'The Right of Way' dire... Offset 200
# Processed: In which year was the film 'The Right of Way' dire... Offset 300
# Processed: In which year was the film 'The Right of Way' dire... Offset 400
# Processed: In which year was the film 'The Right of Way' dire... Offset 500
# Processed: In which year were the cases in volume 310 of Unit... Offset 200
# Processed: In which year were the cases in volume 310 of Unit... Offset 300
# Processed: In which year were the cases in volume 310 of Unit... Offset 400
# Processed: In which year were the cases in volume 310 of Unit... Offset 500
# Processed: In which year was the Corridor Plan for Perth adop... Offset 200
# Processed: In which year was the Corridor Plan for Perth adop... Offset 300
# Processed: In which year was the Corridor Plan for Perth adop... Offset 400
# Processed: In which year was the Corridor Plan for Perth adop... Offset 500
# Processed: In which year did Jay Idzes sign a four-year contr... Offset 200
# Processed: In which year did Jay Idzes sign a four-year contr... Offset 300
# Processed: In which year did Jay Idzes sign a four-year contr... Offset 400
# Processed: In which year did Jay Idzes sign a four-year contr... Offset 500
# Processed: In which year was studioMDA, the multidisciplinary... Offset 200
# Processed: In which year was studioMDA, the multidisciplinary... Offset 300
# Processed: In which year was studioMDA, the multidisciplinary... Offset 400
# Processed: In which year was studioMDA, the multidisciplinary... Offset 500
# Processed: In which year did Sonia Deol graduate from the Uni... Offset 200
# Processed: In which year did Sonia Deol graduate from the Uni... Offset 300
# Processed: In which year did Sonia Deol graduate from the Uni... Offset 400
# Processed: In which year did Sonia Deol graduate from the Uni... Offset 500
# Processed: In which year was the South India Championship ten... Offset 200
# Processed: In which year was the South India Championship ten... Offset 300
# Processed: In which year was the South India Championship ten... Offset 400
# Processed: In which year was the South India Championship ten... Offset 500
# Processed: In which year was the Hong Kong Football Associati... Offset 200
# Processed: In which year was the Hong Kong Football Associati... Offset 300
# Processed: In which year was the Hong Kong Football Associati... Offset 400
# Processed: In which year was the Hong Kong Football Associati... Offset 500
# Processed: In which year was the Coldridge Plantation purchas... Offset 200
# Processed: In which year was the Coldridge Plantation purchas... Offset 300
# Processed: In which year was the Coldridge Plantation purchas... Offset 400
# Processed: In which year was the Coldridge Plantation purchas... Offset 500
# Processed: In which year was Bampur District separated from I... Offset 200
# Processed: In which year was Bampur District separated from I... Offset 300
# Processed: In which year was Bampur District separated from I... Offset 400
# Processed: In which year was Bampur District separated from I... Offset 500
# Processed: In which year did James Francis Burke graduate fro... Offset 200
# Processed: In which year did James Francis Burke graduate fro... Offset 300
# Processed: In which year did James Francis Burke graduate fro... Offset 400
# Processed: In which year did James Francis Burke graduate fro... Offset 500
# Completed experiments for 176 QA pairs over selected offsets.

# %%
combined_filename = f"experiment_results_year_selected_{len(experiment_results)}_full_extend.json"
combined_filepath = os.path.join(data_path, combined_filename)

with open(combined_filepath, "w") as f:
    json.dump(experiment_results, f, indent=2)

print(f"Experiment results saved to {combined_filepath}")
