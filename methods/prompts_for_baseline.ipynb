# %%
# prompts

# %%
DEBATER = {
    "initial_answer_prompt_with_context": (
    "Your job is to answer questions related to the year of occurrence for events.\n"
    "Your output should JUST be the year (YYYY). Do NOT respond in full sentences.\n"
    "If unsure, give your best guess.\n\n"
    "Example Question:\n"
    "Question: Which year did John Brown's raid on Harpers Ferry occur?\n"
    "Example Answer:\n"
    "1859\n\n"
    "Context: {CONTEXT}\n"
    "Question: {QUESTION}\n"
    "Answer:"
),

    "initial_answer_prompt_without_context":(
    "Your job is to answer questions related to the year of occurrence for events.\n"
    "Your output should JUST be the year (YYYY). Do NOT respond in full sentences.\n"
    "If unsure, give your best guess.\n\n"
    "Example Question:\n"
    "Question: Which year did John Brown's raid on Harpers Ferry occur?\n"
    "Example Answer:\n"
    "1859\n\n"
    "Question: {QUESTION}\n"
    "Answer:"
),

    "debate_response_full_history": """Please review the full conversation history below:
{full_history}
Now, Agent {name}, considering your previous answer "{own_answer}" and your opponent's answer "{opponent_answer}" in Round {round_num}, please generate your NEXT RESPONSE in the format:
<argument>{your response}</argument>""",

    "debate_response_last_round": """Please review the most recent round of conversation below:
{last_round}
Now, Agent {name}, considering your previous answer "{own_answer}" and your opponent's answer "{opponent_answer}" in Round {round_num}, please generate your NEXT RESPONSE in the format:
<argument>{your response}</argument>""",

    "debater_ch_instru": """Your task is to critically examine your opponent’s answer, identify inconsistencies, logical errors, and unsupported assumptions, and ask probing questions that require clarification.""",

    "debater_de_instru": """Your role is to defend your original answer. Restate your main argument clearly, then address any challenges with detailed reasoning and evidence.""",

    "debater_sym_instru": """You are required to both defend your own answer and critically challenge your opponent’s answer. Identify any inconsistencies and improve your answer accordingly.""",

    "context_trust_instru": """Before anything else:
1. Assume the provided Context is correct and use it as the basis for your answers.
2. Only question the Context if it contains an impossible fact (e.g., a year beyond 3000 AD).
3. Flag truly impossible Context but do NOT reject plausible Context that merely contradicts general world‐knowledge.""",


    "first_round_thinking": """1. Consider what extra context the judge needs to understand your argument.
2. Think step by step to plan a strong argument.
3. Include supporting evidence or quotes from the provided context.""",

    "second_round_thinking": """1. Identify the biggest flaws in your opponent's argument.
2. Critically evaluate and articulate these issues step by step.
3. Provide supporting evidence or quotes that refute your opponent's points.""",

    "nth_round_thinking": """1. Review the critiques your opponent has made.
2. Construct your counterargument in a step-by-step manner.
3. Include specific evidence or quotes to refute these critiques.""",

    "opening_argument_request": """Now it's your turn to construct your opening argument for why the answer to the question "{QUESTION}" is "{ANSWER_DEFENDING}"."""
}

JUDGE = {
    "judge_sym_instru": """Review the entire debate transcript below and synthesize the arguments from both agents. Determine which points are the most logically sound and well-supported, and then generate a concise final decision.""",

    "judge_asym_instru": """Review the entire debate transcript below and objectively synthesize the arguments from both agents. Evaluate which points are most logically sound and well-supported, then generate a concise final decision.""",

    "final_decision_prompt": """Based on the above transcript, please generate your FINAL DECISION, which answer do you support, if it is a year, give the answer in 4 digit number.
Your response must start with a line in the exact format:
final answer: YYYY"""
}

# %%
YEAR_PROMPT = (
    "Your job is to answer questions related to the year of occurrence for events.\n"
    "Your output should JUST be the four-digit year (YYYY) and nothing else.\n"
    "Do NOT respond in full sentences.\n"
    "If unsure, give your best guess.\n\n"
    "Example Question:\n"
    "Question: Which year did John Brown's raid on Harpers Ferry occur?\n"
    "Answer: 1859\n\n"
    "Question: {question}\n"
    "Answer:"
)

# %%
SELF_ASK_PROMPT = """\
You are a reasoning assistant.
You **must** answer in **exactly three lines** and nothing else, following the template below.
If you do not know the answer with certainty, still give your best 4-digit guess.

Template — use these tags verbatim (replace the text in angle-brackets):

Sub-question: <one clarifying question you ask yourself>
Sub-answer:   <concise answer to that sub-question>
Final answer: <4-digit year>

Context: {CONTEXT}
Question: {QUESTION}
Sub-question:
Sub-answer:
Final answer:
"""

# %%
INITIAL_PROMPT = """You are Agent {AGENT_ID}.
You will be asked the question below. Think step by step and output **one
4-digit year** boxed on its own line, e.g.  ▢ 1859 ▢ .

If you are not 100 % certain, you must still give your *best educated guess*
rather than “Unknown”, “N/A”, or a range.

Question:
{QUESTION}
Context:
{CONTEXT}
"""

CONSENSUS_PROMPT = """You are Agent {AGENT_ID}.
And here is the original question:
Question:
{QUESTION}
Context:
{CONTEXT}
Below are all agents’ answers from the previous round:

{PEER_ANSWERS}

Your own last answer was: {OWN_ANSWER}

Please do ALL of the following:
1. Briefly view peer's answer
2. Re-examine your answer.
   *If the evidence is inconclusive, choose the year that seems **most
   plausible**; do **NOT** answer “Unknown”.*
3. Output **one 4-digit year**, boxed on its own line, e.g.  ▢ 1859 ▢ .
   Do not include any other boxed numbers.

Keep the whole response under 6 sentences.
"""

# %%
R_DEBATER = {
    "initial_answer_prompt_with_context": (
    "Your job is to answer questions related to the year of occurrence for events.\n"
    "Your output should JUST be the year (YYYY). Do NOT respond in full sentences.\n"
    "If unsure, give your best guess.\n\n"
    "Example Question:\n"
    "Question: Which year did John Brown's raid on Harpers Ferry occur?\n"
    "Example Answer:\n"
    "1859\n\n"
    "Context: {CONTEXT}\n"
    "Question: {QUESTION}\n"
    "Answer:"
    ),

    "initial_answer_prompt_without_context":(
    "Your job is to answer questions related to the year of occurrence for events.\n"
    "Your output should JUST be the year (YYYY). Do NOT respond in full sentences.\n"
    "If unsure, give your best guess.\n\n"
    "Example Question:\n"
    "Question: Which year did John Brown's raid on Harpers Ferry occur?\n"
    "Example Answer:\n"
    "1859\n\n"
    "Question: {QUESTION}\n"
    "Answer:"
    ),

    "defender_initial": (
        "You are **Context Defender**.\n"
        "Your role is to defend the provided Context as **reasonable, trustworthy, and internally consistent**.\n\n"
        "**Your tasks:**\n"
        "- Quote directly from the Context to support its validity.\n"
        "- Highlight consistency with known facts or plausible scenarios.\n"
        "- Address any potential doubts proactively.\n\n"
        "Instructions:\n"
        "- Stay focused ONLY on information present in the Context.\n"
        "- Be logical, factual, and persuasive.\n\n"
        "Context:\n{CONTEXT}\n\n"
        "Question:\n{QUESTION}\n\n"
        "Respond with your opening argument inside:\n"
        "<argument>YOUR TEXT HERE</argument>"),
    "critic_initial": (
        "You are **Context Critic**.\n"
        "Your role is to challenge the provided Context as **unreasonable, flawed, or inconsistent**.\n\n"
        "**Your tasks:**\n"
        "- Identify any logical gaps, contradictions, or factual errors.\n"
        "- Point out any inconsistencies with general knowledge or real-world plausibility.\n"
        "- Emphasize uncertainties, ambiguities, or implausible elements.\n\n"
        "Instructions:\n"
        "- Focus only on the given Context and Question.\n"
        "- Maintain a critical but professional tone.\n\n"
        "Context:\n{CONTEXT}\n\n"
        "Question:\n{QUESTION}\n\n"
        "Respond with your opening argument inside:\n"
        "<argument>YOUR TEXT HERE</argument>"
        ),
    "critic_initial_refined": (
        "You are **Context Critic**.\n"
        "Your role is to **critically evaluate** the provided Context and determine if it contains any flaws, contradictions, or implausibilities.\n\n"
        "**Your tasks:**\n"
        "- If you identify real, well-supported issues, point them out clearly and logically.\n"
        "- If you find no significant problems, you may state that the Context appears reasonable.\n"
        "- Base your judgment strictly on the information in the Context and general world knowledge — avoid speculation or exaggerated criticisms.\n\n"
        "Instructions:\n"
        "- Maintain a careful, logical, and professional tone.\n"
        "- Focus only on genuine flaws or uncertainties.\n\n"
        "Context:\n{CONTEXT}\n\n"
        "Question:\n{QUESTION}\n\n"
        "Respond with your opening argument inside the tags:\n"
        "<argument>YOUR TEXT HERE</argument>"
        ),
    "debate_followup": (
        "Debate transcript so far:\n"
        "{full_history}\n\n"
        "Now, Agent {name}, you are the **{role}**.\n"
        "Your last argument was:\n\"{own_argument}\"\n\n"
        "Your opponent's last argument was:\n\"{opponent_argument}\"\n\n"
        "**Your task:**\n"
        "- Respond directly to the opponent’s latest points.\n"
        "- Reinforce your own position with new arguments, clarifications, or counterexamples.\n\n"
        "Respond inside the tags:\n"
        "<argument>YOUR TEXT HERE</argument>"),
    "defender_followup": (
        "Debate transcript so far:\n"
        "{full_history}\n\n"
        "Now, Agent {name}, you are the **Context Defender**.\n"
        "Your job is to **defend the provided Context as reasonable, internally consistent, and trustworthy**.\n"
        "Continue to reinforce the plausibility of the Context, using logic, quotes, and clarifications as needed.\n\n"
        "**Your task:**\n"
        "- Respond directly to the opponent’s latest points.\n"
        "- Reinforce your own position with new arguments, evidence, or explanations.\n\n"
        "Respond inside the tags:\n"
        "<argument>YOUR TEXT HERE</argument>"
    ),
    "critic_followup": (
        "Debate transcript so far:\n"
        "{full_history}\n\n"
        "Now, Agent {name}, you are the **Context Critic**.\n"
        "Your job is to **challenge the provided Context by identifying flaws, inconsistencies, or implausibilities**.\n"
        "Continue to expose weaknesses or contradictions in the Context, using logical critique and examples.\n\n"
        "**Your task:**\n"
        "- Respond directly to the opponent’s latest points.\n"
        "- Strengthen your criticism with new challenges, counterexamples, or logical reasoning.\n\n"
        "Respond inside the tags:\n"
        "<argument>YOUR TEXT HERE</argument>"
    ),
    "critic_followup_concise": (
        "Debate transcript so far:\n"
        "{full_history}\n\n"
        "Now, Agent {name}, you are the **Context Critic**.\n"
        "Your job is to **challenge the provided Context by identifying flaws, inconsistencies, or implausibilities**.\n"
        "Continue to expose weaknesses or contradictions in the Context, using logical critique and examples.\n\n"
        "**Your task:**\n"
        "- Respond directly to the opponent’s latest points.\n"
        "- Strengthen your criticism with new challenges, counterexamples, or logical reasoning.\n"
        "- You must write no more than **three sentences**.\n\n"
        "Respond inside the tags:\n"
        "<argument>YOUR TEXT HERE</argument>"
    ),
    "defender_followup_concise": (
        "Debate transcript so far:\n"
        "{full_history}\n\n"
        "Now, Agent {name}, you are the **Context Defender**.\n"
        "Your job is to **defend the provided Context as reasonable, internally consistent, and trustworthy**.\n"
        "Continue to reinforce the plausibility of the Context, using logic, quotes, and clarifications as needed.\n\n"
        "**Your task:**\n"
        "- Respond directly to the opponent’s latest points.\n"
        "- Reinforce your own position with new arguments, evidence, or explanations.\n"
        "- You must write no more than **three sentences**.\n\n"
        "Respond inside the tags:\n"
        "<argument>YOUR TEXT HERE</argument>"
    ),
    "critic_followup_concise_reliable_agree": (
        "Debate transcript so far:\n"
        "{full_history}\n\n"
        "Now, Agent {name}, you are the **Context Critic**.\n"
        "Your job is to **challenge the provided Context by identifying real flaws, contradictions, or implausibilities, but only if they are well-supported and reasonable**.\n"
        "Prioritize **credible, logically sound, and meaningful criticisms** over speculative or weak attacks.\n"
        "**If you find no significant flaws worth criticizing, you may agree with the Defender and acknowledge the Context's overall reasonableness.**\n\n"
        "**Your task:**\n"
        "- Respond directly to the opponent’s latest points.\n"
        "- Strengthen your position with strong, reliable challenges OR acknowledge the Defender’s valid points.\n"
        "- Avoid making exaggerated, speculative, or poorly supported claims.\n"
        "- You must write no more than **three sentences**.\n\n"
        "Respond inside the tags:\n"
        "<argument>YOUR TEXT HERE</argument>"
    ),
    "decider_initial": (
        "You are the **Context Decider**.\n"
        "Your job is to **carefully evaluate** the provided Context.\n\n"
        "**Your approach:**\n"
        "- First, assess whether the Context is reasonable, internally consistent, and trustworthy.\n"
        "- If you find the Context reasonable, you should agree with the Defender and explain why.\n"
        "- If you find major flaws, contradictions, or implausibilities, you should challenge the Context clearly and logically.\n\n"
        "**Important:**\n"
        "- Base your evaluation strictly on evidence, logic, and consistency with known facts.\n"
        "- Avoid exaggerated, speculative, or unsupported criticisms.\n\n"
        "Context:\n{CONTEXT}\n\n"
        "Question:\n{QUESTION}\n\n"
        "Respond with your initial evaluation and argument inside the tags:\n"
        "<argument>YOUR TEXT HERE</argument>"
    ),
    "decider_followup": (
        "Debate transcript so far:\n"
        "{full_history}\n\n"
        "Now, Agent {name}, you are the **Context Decider**.\n"
        "Your job is to **carefully evaluate** the Context throughout the debate.\n"
        "**If you agree with the Defender's points and believe the Context remains reasonable, continue to support it.**\n"
        "**If you find credible flaws or weaknesses, continue to challenge it clearly and logically.**\n\n"
        "**Your task:**\n"
        "- Respond directly to the opponent’s latest points.\n"
        "- Either strengthen your agreement OR strengthen your challenge, based on the evidence.\n"
        "- Focus on clear, logical reasoning only.\n"
        "- You must write no more than **three sentences**.\n\n"
        "Respond inside the tags:\n"
        "<argument>YOUR TEXT HERE</argument>"
    )
    }


R_JUDGE = {
"judge_instruction": (
    "You are the **Judge**.\n"
    "Your role is to evaluate the complete debate and decide whether the provided Context is ultimately REASONABLE or UNREASONABLE.\n\n"
    "**Instructions:**\n"
    "- Carefully weigh the strengths of the arguments from both the Context Defender and the Context Critic.\n"
    "- Base your decision solely on the debate content — do not introduce outside knowledge.\n\n"
    "Debate Transcript:\n{full_history}\n\n"
    "Output exactly one line, following this format (no other commentary):\n"
    "final decision: REASONABLE\n"
    "or\n"
    "final decision: UNREASONABLE"
),
}

R_Transcript = {
    "debate_transcript_template": (
        "Debate Transcript\n"
        "=================\n\n"
        "{rounds}"
    ),

    "single_round_template": (
        "Round {round_number}:\n"
        "-----------------\n"
        "Defender's argument:\n"
        "<argument>\n{defender_argument}\n</argument>\n\n"
        "Critic's argument:\n"
        "<argument>\n{critic_argument}\n</argument>\n\n"
    )
}
